# %% [markdown]
# # Exercice 1

# %%
print("Hello world")
print("Hello world")
print("Hello world")
print("Hello world")
# Out:
# Hello world
# Hello world
# Hello world
# Hello world

# %% [markdown]
# # Exercice 2

# %%
print(f"99 à la puissance de 3 fois 8 est : {(99^3)*8}")
# Out:
# 99 à la puissance de 3 fois 8 est : 768

# %% [markdown]
# # Exercice 3: Quelle est la sortie?

# %% [markdown]
#  Ma supposition : la sortie est FALSE

# %%
15 < 8
# Out:
# False

# %%
5 < 3
3 == 3
3 == "3"
5 < 3
"3" > 3
"Hello" == "hello"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1527/2561955399.py in <cell line: 0>()
#       3 3 == "3"
#       4 5 < 3
# ----> 5 "3" > 3
#       6 "Hello" == "hello"
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %% [markdown]
# # Exercice 4

# %%
computer_brand = "DELL"

# %%
print(f"I have a {computer_brand} computer.")
# Out:
# I have a DELL computer.

# %%
name = "Yeo"
age = 25
shoe_size = 42
info = f"Je m'appelle {name}, j'ai {age} ans, ma pointure est {shoe_size} et j'adore programmer en Python !"

print(info)
# Out:
# Je m'appelle Yeo, j'ai 25 ans, ma pointure est 42 et j'adore programmer en Python !

# %% [markdown]
# # Exercice 6

# %%
a = 10
b = 5
if a > b :
  print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # Exercice 7

# %%
number = int(input("Entrez un nombre : "))
if number % 2 == 0:
    print(f"Le nombre {number} est pair.")
else:
    print(f"Le nombre {number} est impair.")
# Out:
# Entrez un nombre : 30
# Le nombre 30 est pair.

# %% [markdown]
# # Exercice 8

# %%
user_name = input("Quel est ton nom ? ")
name = "Yeo"
if user_name.lower() == name.lower():
    print(f"C'est incroyable ! On s'appelle tous les deux {name}. On est comme des jumeaux  !")
else:
    print(f"Enchanté {user_name} ! Moi c'est {name}. C'est un joli prénom, mais le mien a quand même du style ! ")
# Out:
# Quel est ton nom ? trace
# Enchanté trace  ! Moi c'est Yeo. C'est un joli prénom, mais le mien a quand même du style !

# %% [markdown]
# # Exercice 9

# %%
taille = int(input("Veuillez entrer votre taille en centimètres : "))
if taille > 145:
    print("Vous êtes assez grand pour rouler.")
else:
    print("Désolé, vous devez grandir encore un peu plus pour pouvoir rouler.")
# Out:
# Veuillez entrer votre taille en centimètres : 47
# Désolé, vous devez grandir encore un peu plus pour pouvoir rouler.
