# %%
birthdate = input("Please enter your birthdate (DD/MM/YYYY): ")
print("      ___iiiii___")
print("      |:H:a:p:p:y:|")
print("    __|___________|__")
print("   |^^^^^^^^^^^^^^^^^|")
print("   |:B:i:r:t:h:d:a:y:|")
# Out:
# Please enter your birthdate (DD/MM/YYYY): 10/12/2024
#       ___iiiii___
#       |:H:a:p:p:y:|
#     __|___________|__
#    |^^^^^^^^^^^^^^^^^|
#    |:B:i:r:t:h:d:a:y:|
